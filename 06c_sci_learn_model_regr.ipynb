# %% [markdown]
# #### Picking a ML Model for a Regression Problem
# - Using California Housing Dataset from Scikit-learn Website
# - The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars ($100,000).

# %%
# Importing our tools
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# %%
# Get California Housing Dataset
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
housing # we have a dictionary here as data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
housing_df = pd.DataFrame(housing["data"], columns = housing["feature_names"])
housing_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
# we are constructing our data, now adding target column: MedHouseVal
# housing_df["MedHouseVal"] = housing["target"]
housing_df["target"] = housing["target"]
housing_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# ...

# %%
housing_df = housing_df.drop("MedHouseVal", axis=1)
housing_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/dci-student/Python/A_Self_Study/data_science_ml_notes/06c_sci_learn_model_regr.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/home/dci-student/Python/A_Self_Study/data_science_ml_notes/06c_sci_learn_model_regr.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> housing_df = housing_df.drop("MedHouseVal", axis=1)
#       <a href='vscode-notebook-cell:/home/dci-student/Python/A_Self_Study/data_science_ml_notes/06c_sci_learn_model_regr.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> housing_df
#
# File ~/.local/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %% [markdown]
# ##### Now use the features (8 Columns "MedInc"- "Longitude") to estimate "target":
# - first splitting the data to X(features) and y (target)

# %%
# Import Algorithm/estimator (experiment and pick most suitable model from cheatsheet)
# imported "Ridge" above in the imports code box

# Setup random seed
np.random.seed(42)

# create data
X = housing_df.drop("target", axis=1)
y = housing_df["target"] # Median house price in $ 100.000s

# Split the data into train and test sets
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size=0.2)

#instantiate and fit the model (on the training set)
model = Ridge()
model.fit(X_train,y_train)

# Check score of the model (on the test set) 
model.score(X_test,y_test)
# Out:
# 0.5758549611440127

# %% [markdown]
# - ***Coefficient of Determination:***  assesses how strong the linear relationship is between two variables and is heavily relied on by investors when conducting trend analysis.
# - R**2 = 1- RSS/TSS
# - R**2 = coefficient of determination
# - RSS = sum of squares of residuals
# - TSS = total sum of squares

# %% [markdown]
# ##### Trying to Improve estimation with different models

# %%
#:Lasso
from sklearn.linear_model import Lasso
model = Lasso()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.2841671821008396

# %%
# Elastic-Net
from sklearn.linear_model import ElasticNet
model = ElasticNet()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.41655189098028245

# %% [markdown]
# ##### Trying Ensemble Methods:
# - Combination of smaller models to try and make better predictions than just a single model.
# - https://scikit-learn.org/stable/modules/ensemble.html
# - RandomForest: Based on decision tree :
# - https://willkoehrsen.github.io/data%20science/machine%20learning/random-forest-simple-explanation/

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.8067600041906792
